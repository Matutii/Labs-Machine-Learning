# %%
import pandas as pd

# %%
edades = pd.Series([1,2,3,4,5], name = "Edad")

# %%
datos = pd.DataFrame({
    "nombre": ["Juan", "Pedro", "Maria", "Ana", "Luis"],
    "edad": [25, 30, 22, 28, 35],
    "estado": ["Activo", "Inactivo", "Activo", "Activo", "Inactivo"]
})

# %%
datos
# Out:
#   nombre  edad    estado
# 0   Juan    25    Activo
# 1  Pedro    30  Inactivo
# 2  Maria    22    Activo
# 3    Ana    28    Activo
# 4   Luis    35  Inactivo

# %%
registro = [
    {"nombre": "Juan", "edad": 25, "estado": "Activo"},
    {"nombre": "Pedro", "edad": 30, "estado": "Inactivo"},
]
pd.DataFrame(registro)
# Out:
#   nombre  edad    estado
# 0   Juan    25    Activo
# 1  Pedro    30  Inactivo

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos = pd.concat([datos,pd.DataFrame(registro)], ignore_index=True)
datos
# Out:
#   nombre  edad    estado
# 0   Juan    25    Activo
# 1  Pedro    30  Inactivo
# 2  Maria    22    Activo
# 3    Ana    28    Activo
# 4   Luis    35  Inactivo
# 5   Juan    25    Activo
# 6  Pedro    30  Inactivo

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris_data = load_iris()
iris = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)

iris.iloc[:, :4].plot()
# Out:
# <Axes: >

# %%
iris.iloc[:, :4].plot()
# Out:
# <Axes: >

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
columnas = iris.iloc[:, :4].columns.to_list()
columnas
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
for i, row in iris.iterrows():
    print(row)
# Out:
# sepal length (cm)    5.1
# sepal width (cm)     3.5
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 0, dtype: float64
# sepal length (cm)    4.9
# sepal width (cm)     3.0
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 1, dtype: float64
# sepal length (cm)    4.7
# sepal width (cm)     3.2
# petal length (cm)    1.3
# petal width (cm)     0.2
# Name: 2, dtype: float64
# sepal length (cm)    4.6
# sepal width (cm)     3.1
# petal length (cm)    1.5
# petal width (cm)     0.2
# Name: 3, dtype: float64
# sepal length (cm)    5.0
# sepal width (cm)     3.6
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 4, dtype: float64
# sepal length (cm)    5.4
# sepal width (cm)     3.9
# petal length (cm)    1.7
# petal width (cm)     0.4
# Name: 5, dtype: float64
# sepal length (cm)    4.6
# sepal width (cm)     3.4
# petal length (cm)    1.4
# petal width (cm)     0.3
# Name: 6, dtype: float64
# sepal length (cm)    5.0
# sepal width (cm)     3.4
# ...

# %%
print(iris.columns.tolist())
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
from sklearn.datasets import load_iris

data = load_iris()
iris["species"] = data.target_names[data.target]

especies = iris["species"].unique().tolist()
especies
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
especies = iris["species"].unique().tolist()
especies
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
test =iris.sample(frac=0.2)

# %%
test_iris = pd.DataFrame()

especies = iris["species"].unique()
for especie in especies:
    test_iris = pd.concat([test_iris, iris[iris["species"] == especie].sample(frac=0.2)])

test_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 30                 4.8               3.1                1.6               0.2
# 35                 5.0               3.2                1.2               0.2
# 17                 5.1               3.5                1.4               0.3
# 16                 5.4               3.9                1.3               0.4
# 10                 5.4               3.7                1.5               0.2
# 23                 5.1               3.3                1.7               0.5
# 18                 5.7               3.8                1.7               0.3
# 39                 5.1               3.4                1.5               0.2
# 3                  4.6               3.1                1.5               0.2
# 24                 4.8               3.4                1.9               0.2
# 85                 6.0               3.4                4.5               1.6
# ...

# %%
for especie in especies:
    print(test_iris[test_iris["species"] == especie].count())
# Out:
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64

# %%
especies = test_iris["species"].unique()

for especie in especies:
    print(test_iris[test_iris["species"] == especie].count())
# Out:
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64

# %%
test_iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
for especie in especies:
    print(test_iris[test_iris["species"] == especie].count())
# Out:
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64
# sepal length (cm)    10
# sepal width (cm)     10
# petal length (cm)    10
# petal width (cm)     10
# species              10
# dtype: int64

# %%
caracteristicas = iris.iloc[:, :4].columns.tolist()
caracteristicas
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
for especie in especies:
    datos_especie = iris[iris["species"] == especie]
    for caracteristica in caracteristicas:
        valores = datos_especie[caracteristica].tolist()
        total = 0
        minimo = valores[0]
        maximo = valores[0]
        for valor in valores:
            total = total + valor
            if valor < minimo:
                minimo = valor
            if valor > maximo:
                maximo = valor

        promedio = total / len(valores)

        print(f"{especie} - {caracteristica}: promedio = {promedio} +- {maximo - minimo}")
# Out:
# setosa - sepal length (cm): promedio = 5.005999999999999 +- 1.5
# setosa - sepal width (cm): promedio = 3.428000000000001 +- 2.1000000000000005
# setosa - petal length (cm): promedio = 1.4620000000000002 +- 0.8999999999999999
# setosa - petal width (cm): promedio = 0.2459999999999999 +- 0.5
# versicolor - sepal length (cm): promedio = 5.936 +- 2.0999999999999996
# versicolor - sepal width (cm): promedio = 2.7700000000000005 +- 1.4
# versicolor - petal length (cm): promedio = 4.26 +- 2.0999999999999996
# versicolor - petal width (cm): promedio = 1.3259999999999998 +- 0.8
# virginica - sepal length (cm): promedio = 6.587999999999998 +- 3.0
# virginica - sepal width (cm): promedio = 2.9739999999999998 +- 1.5999999999999996
# virginica - petal length (cm): promedio = 5.552 +- 2.4000000000000004
# virginica - petal width (cm): promedio = 2.026 +- 1.1

# %%
rangos = {}
for especie in especies:
    rangos[especie] = train_iris.iloc[:, :4].loc[train_iris["species"] == especie].agg(["mean", "min", "max"]).to_dict()
rangos
# Out:
# {'setosa': {'sepal length (cm)': {'mean': 5.0025, 'min': 4.4, 'max': 5.8},
#   'sepal width (cm)': {'mean': 3.4524999999999997, 'min': 2.3, 'max': 4.4},
#   'petal length (cm)': {'mean': 1.45, 'min': 1.0, 'max': 1.9},
#   'petal width (cm)': {'mean': 0.25, 'min': 0.1, 'max': 0.6}},
#  'versicolor': {'sepal length (cm)': {'mean': 5.9475, 'min': 4.9, 'max': 7.0},
#   'sepal width (cm)': {'mean': 2.7675, 'min': 2.0, 'max': 3.4},
#   'petal length (cm)': {'mean': 4.2575, 'min': 3.0, 'max': 5.1},
#   'petal width (cm)': {'mean': 1.3225, 'min': 1.0, 'max': 1.7}},
#  'virginica': {'sepal length (cm)': {'mean': 6.6325, 'min': 4.9, 'max': 7.7},
#   'sepal width (cm)': {'mean': 2.9549999999999996, 'min': 2.5, 'max': 3.8},
#   'petal length (cm)': {'mean': 5.602500000000001, 'min': 4.5, 'max': 6.9},
#   'petal width (cm)': {'mean': 2.0425, 'min': 1.4, 'max': 2.5}}}

# %%
test_iris = pd.DataFrame()

for especie in especies:
    test_iris = pd.concat([test_iris, iris[iris["species"] == especie].sample(frac=0.20)])

test_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 20                 5.4               3.4                1.7               0.2
# 36                 5.5               3.5                1.3               0.2
# 13                 4.3               3.0                1.1               0.1
# 9                  4.9               3.1                1.5               0.1
# 48                 5.3               3.7                1.5               0.2
# 23                 5.1               3.3                1.7               0.5
# 49                 5.0               3.3                1.4               0.2
# 44                 5.1               3.8                1.9               0.4
# 25                 5.0               3.0                1.6               0.2
# 47                 4.6               3.2                1.4               0.2
# 66                 5.6               3.0                4.5               1.5
# ...

# %%
train_iris = iris[~iris.index.isin(test_iris.index)]
train_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 143                6.8               3.2                5.9               2.3
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
#
#        species
# 0       setosa
# ...

# %%
caracteristicas
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
especies
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
rangos
# Out:
# {'setosa': {'sepal length (cm)': {'mean': 5.0025, 'min': 4.4, 'max': 5.8},
#   'sepal width (cm)': {'mean': 3.4524999999999997, 'min': 2.3, 'max': 4.4},
#   'petal length (cm)': {'mean': 1.45, 'min': 1.0, 'max': 1.9},
#   'petal width (cm)': {'mean': 0.25, 'min': 0.1, 'max': 0.6}},
#  'versicolor': {'sepal length (cm)': {'mean': 5.9475, 'min': 4.9, 'max': 7.0},
#   'sepal width (cm)': {'mean': 2.7675, 'min': 2.0, 'max': 3.4},
#   'petal length (cm)': {'mean': 4.2575, 'min': 3.0, 'max': 5.1},
#   'petal width (cm)': {'mean': 1.3225, 'min': 1.0, 'max': 1.7}},
#  'virginica': {'sepal length (cm)': {'mean': 6.6325, 'min': 4.9, 'max': 7.7},
#   'sepal width (cm)': {'mean': 2.9549999999999996, 'min': 2.5, 'max': 3.8},
#   'petal length (cm)': {'mean': 5.602500000000001, 'min': 4.5, 'max': 6.9},
#   'petal width (cm)': {'mean': 2.0425, 'min': 1.4, 'max': 2.5}}}

# %%
test_iris[:1]["petal length (cm)"].values[0]
# Out:
# np.float64(1.7)

# %%
rangos[0]["petal length (cm)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 rangos[0]["petal length (cm)"]
#
# KeyError: 0

# %%
for key in rangos:
    print(rangos[key])
# Out:
# {'sepal length (cm)': {'mean': 5.0025, 'min': 4.4, 'max': 5.8}, 'sepal width (cm)': {'mean': 3.4524999999999997, 'min': 2.3, 'max': 4.4}, 'petal length (cm)': {'mean': 1.45, 'min': 1.0, 'max': 1.9}, 'petal width (cm)': {'mean': 0.25, 'min': 0.1, 'max': 0.6}}
# {'sepal length (cm)': {'mean': 5.9475, 'min': 4.9, 'max': 7.0}, 'sepal width (cm)': {'mean': 2.7675, 'min': 2.0, 'max': 3.4}, 'petal length (cm)': {'mean': 4.2575, 'min': 3.0, 'max': 5.1}, 'petal width (cm)': {'mean': 1.3225, 'min': 1.0, 'max': 1.7}}
# {'sepal length (cm)': {'mean': 6.6325, 'min': 4.9, 'max': 7.7}, 'sepal width (cm)': {'mean': 2.9549999999999996, 'min': 2.5, 'max': 3.8}, 'petal length (cm)': {'mean': 5.602500000000001, 'min': 4.5, 'max': 6.9}, 'petal width (cm)': {'mean': 2.0425, 'min': 1.4, 'max': 2.5}}

# %%
def estaEnelIntervalo(valor, promedio, minimo, maximo):
    dif = max - minimo 
    if promedio-dif < valor < promedio+dif:
        return True
    else: return

# %%
for index, row in test_iris.iterrows():
    print(row["sepal length (cm)"])
    for key in rangos:
        print(rangos[key])
        for caracteristica in caracteristicas:
            print(estaEnelIntervalo(row[caracteristica], **rangos[key][caracteristica]))
        break
    break
# Out:
# 5.4
# {'sepal length (cm)': {'mean': 5.0025, 'min': 4.4, 'max': 5.8}, 'sepal width (cm)': {'mean': 3.4524999999999997, 'min': 2.3, 'max': 4.4}, 'petal length (cm)': {'mean': 1.45, 'min': 1.0, 'max': 1.9}, 'petal width (cm)': {'mean': 0.25, 'min': 0.1, 'max': 0.6}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 6
#       4     print(rangos[key])
#       5     for caracteristica in caracteristicas:
# ----> 6         print(estaEnelIntervalo(row[caracteristica], **rangos[key][caracteristica]))
#       7     break
#       8 break
#
# TypeError: estaEnelIntervalo() got an unexpected keyword argument 'mean'
